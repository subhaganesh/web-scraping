# %% [markdown]
# # creating a web driver

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
website='https://www.adamchoi.co.uk/overs/detailed'

# %%
path=r'"C:\Users\subha\OneDrive\Desktop\chromedriver.exe"'

# %%
driver=webdriver.Chrome(path)
# Out:
# C:\Users\subha\AppData\Local\Temp\ipykernel_11688\3558225199.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(path)

# %%
driver.get(website)

# %%
#driver.quit()

# %% [markdown]
# # finding elements with selenium

# %% [raw]
# Here by using driver we will scrape websites that run on java script
# we can find elements using id,name,xpath,linktext,classname,tagname,cssselector

# %% [raw]
# to find sigle element:
# driver.find_element_by_id('id')
# #driver.find_element_by_class_name('class_name')
# #driver.find_element_by_xpath('//tag[@attributename="value"]')
# #driver.find_element_by_tag_name('h1')  'p' 'div'
# driver.find_element_by_css_selector()
# driver.find_element_by_name()
# driver.find_element_by_link_text()

# %% [raw]
# to find multiple element:
# add s with element
# driver.find_elements_by_class_name('class_name')

# %% [raw]
# # we can do more with selenium
# dropdowns
# logins
# waits

# %% [markdown]
# # clicking on a button

# %%
all_matches_button=driver.find_element(By.XPATH, '//label[@analytics-event="All matches"]')
all_matches_button.click()

# %% [markdown]
# # extracting data from a table

# %%
#to find single element
matches=driver.find_element(By.TAG_NAME, 'tr')
matches.text
# Out:
# '05-08-2022 Crystal Palace 0 - 2 Arsenal'

# %%
#to find multiple elements
matches= driver.find_elements(By.TAG_NAME, 'tr')


for match in matches:
    print(match.text)
# Out:
# 05-08-2022 Crystal Palace 0 - 2 Arsenal
# 13-08-2022 Arsenal 4 - 2 Leicester
# 20-08-2022 Bournemouth 0 - 3 Arsenal
# 27-08-2022 Arsenal 2 - 1 Fulham
# 31-08-2022 Arsenal 2 - 1 Aston Villa
# 04-09-2022 Man United 3 - 1 Arsenal
# 18-09-2022 Brentford 0 - 3 Arsenal
# 01-10-2022 Arsenal 3 - 1 Tottenham
# 09-10-2022 Arsenal 3 - 2 Liverpool
# 16-10-2022 Leeds 0 - 1 Arsenal
# 23-10-2022 Southampton 1 - 1 Arsenal
# 30-10-2022 Arsenal 5 - 0 Nott'm Forest
# 06-11-2022 Chelsea 0 - 1 Arsenal
# 12-11-2022 Wolves 0 - 2 Arsenal
# 26-12-2022 Arsenal 3 - 1 West Ham
# 31-12-2022 Brighton 2 - 4 Arsenal
# 03-01-2023 Arsenal 0 - 0 Newcastle
# 15-01-2023 Tottenham 0 - 2 Arsenal
# 22-01-2023 Arsenal 3 - 2 Man United
# 04-02-2023 Everton 1 - 0 Arsenal
# 11-02-2023 Arsenal 1 - 1 Brentford
# 15-02-2023 Arsenal 1 - 3 Man City
# 18-02-2023 Aston Villa 2 - 4 Arsenal
# 25-02-2023 Leicester 0 - 1 Arsenal
# 01-03-2023 Arsenal 4 - 0 Everton
# 04-03-2023 Arsenal 3 - 2 Bournemouth
# 12-03-2023 Fulham 0 - 3 Arsenal
# ...

# %%
date=[]
home_team=[]
score=[]
away_team=[]

for match in matches:                                             #|//tr|/td[]
    date.append(match.find_element(By.XPATH, './td[1]').text)     #|  . |/td[] 
    home_team.append(match.find_element(By.XPATH, './td[2]').text)
    score.append(match.find_element(By.XPATH, './td[3]').text)
    away_team.append(match.find_element(By.XPATH, './td[4]').text)

# %% [markdown]
# # exporting data to a csv file with pandas

# %%
data = {'date': date, 'home_team':home_team, 'score':score,'away_team':away_team}
data
# Out:
# {'date': ['05-08-2022',
#   '13-08-2022',
#   '20-08-2022',
#   '27-08-2022',
#   '31-08-2022',
#   '04-09-2022',
#   '18-09-2022',
#   '01-10-2022',
#   '09-10-2022',
#   '16-10-2022',
#   '23-10-2022',
#   '30-10-2022',
#   '06-11-2022',
#   '12-11-2022',
#   '26-12-2022',
#   '31-12-2022',
#   '03-01-2023',
#   '15-01-2023',
#   '22-01-2023',
#   '04-02-2023',
#   '11-02-2023',
#   '15-02-2023',
#   '18-02-2023',
#   '25-02-2023',
#   '01-03-2023',
#   '04-03-2023',
#   '12-03-2023',
#   '19-03-2023',
#   '01-04-2023',
#   '09-04-2023',
#   '16-04-2023',
#   '21-04-2023',
#   '26-04-2023',
#   '02-05-2023',
#   '06-08-2022',
#   '13-08-2022',
#   '20-08-2022',
#   '28-08-2022',
#   '31-08-2022',
#   '03-09-2022',
#   '16-09-2022',
#   '02-10-2022',
#   '10-10-2022',
#   '16-10-2022',
#   '20-10-2022',
#   '23-10-2022',
#   '29-10-2022',
#   '06-11-2022',
#   '13-11-2022',
#   '26-12-2022',
#   '01-01-2023',
#   '04-01-2023',
#   '13-01-2023',
#   '21-01-2023',
#   '04-02-2023',
# ...

# %%
import pandas as pd
df = pd.DataFrame(data)
df.to_csv('football_data.csv',index=False)
df
# Out:
#            date       home_team  score       away_team
# 0    05-08-2022  Crystal Palace  0 - 2         Arsenal
# 1    13-08-2022         Arsenal  4 - 2       Leicester
# 2    20-08-2022     Bournemouth  0 - 3         Arsenal
# 3    27-08-2022         Arsenal  2 - 1          Fulham
# 4    31-08-2022         Arsenal  2 - 1     Aston Villa
# ..          ...             ...    ...             ...
# 653  08-04-2023          Wolves  1 - 0         Chelsea
# 654  15-04-2023          Wolves  2 - 0       Brentford
# 655  22-04-2023       Leicester  2 - 1          Wolves
# 656  25-04-2023          Wolves  2 - 0  Crystal Palace
# 657  29-04-2023        Brighton  ? - ?          Wolves
#
# [658 rows x 4 columns]

# %%
dataframe=pd.read_csv('football_data.csv')
dataframe
# Out:
#            date       home_team  score       away_team
# 0    05-08-2022  Crystal Palace  0 - 2         Arsenal
# 1    13-08-2022         Arsenal  4 - 2       Leicester
# 2    20-08-2022     Bournemouth  0 - 3         Arsenal
# 3    27-08-2022         Arsenal  2 - 1          Fulham
# 4    31-08-2022         Arsenal  2 - 1     Aston Villa
# ..          ...             ...    ...             ...
# 653  08-04-2023          Wolves  1 - 0         Chelsea
# 654  15-04-2023          Wolves  2 - 0       Brentford
# 655  22-04-2023       Leicester  2 - 1          Wolves
# 656  25-04-2023          Wolves  2 - 0  Crystal Palace
# 657  29-04-2023        Brighton  ? - ?          Wolves
#
# [658 rows x 4 columns]

# %% [markdown]
# # selecting elements within a dropdown

# %%
from selenium.webdriver.support.ui import Select
import time

dropdown = Select(driver.find_element(By.ID, "country"))
dropdown.select_by_visible_text('Spain')


time.sleep(3)
