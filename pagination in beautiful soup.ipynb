# %%
from bs4 import BeautifulSoup
import requests

# %%
root='https://subslikescript.com'
website=f'{root}/movies_letter-A'
result=requests.get(website)
content=result.text
soup=BeautifulSoup(content, 'lxml')
print(soup.prettify())
     
#pagination
pagination=soup.find('ul',class_='pagination')
pages=pagination.find_all('li',class_='page-item')
last_page=pages[-2].text

links=[]
for page in range(1, int(last_page)+1)[:2]:  #---[1,92+1]
#https://subslikescript.com/movies_letter-A?page=2
    result=requests.get(f'{website}?page={page}')
    content=result.text
    soup=BeautifulSoup(content, 'lxml')


    box=soup.find('article',class_='main-article')
   
    for link in box.find_all('a', href=True):
        links.append(link['href'])
    

    for link in links:
        
        try:
            print(link)
            result=requests.get(f'{root}/{link}')
            content=result.text
            soup=BeautifulSoup(content, 'lxml')

            box=soup.find('article',class_='main-article')

            title=box.find('h1').get_text()
            transcript=box.find('div',class_='full-script').get_text(strip=True,separator=' ')
            
            
            try:
                with open(f'{title}.txt','w',encoding="utf-8") as file:
                    file.write(transcript)
            except FileNotFoundError:
                print("The file was not found.skip to the next file")
                continue
        except:
            print('------link not working-------')
            print(link)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Movie transcripts with the first letter - "A"
# 	    | Subs like Script
#   </title>
#   <meta a="" content="List of movies' scripts by the first sign " name="description"/>
#   <meta content="transcript, the first letter, movie, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link href="/styles/main.css" media="all" rel="stylesheet" type="text/css"/>
#   <script async="" data-ad-client="ca-pub-6250492176235895" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#  </head>
#  <body>
#   <div class="page-wrapper">
#    <header>
#     <div id="logo">
#      <a href="/" title="Subs like Script - all Movies and TV Shows Transcripts">
#       <span>
#        SUBSLIKESCRIPT
#       </span>
#      </a>
#     </div>
#     <nav>
#      <a href="/movies" target="_self" title="All movies transcripts">
#       Movies
#      </a>
#      <a href="/series" target="_self" title="All Tv Shows transcripts">
#       TV Shows
#      </a>
#     </nav>
#    </header>
#    <div class="main-wrapper">
#     <main class="mainpage">
#      <nav>
#       <ul class="breadcrumb">
#        <li>
#         <a href="/">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="/movies">
#          Movies
#         </a>
#        </li>
#        <li>
#         Movies with the first letter - "A"
#        </li>
#       </ul>
#      </nav>
#      <nav>
#       <form action="/search" class="searchzone" method="get" name="search">
#        <input class="searchbox" name="q" type="text"/>
#        <button class="searchbutton">
#         Search
#        </button>
#       </form>
#      </nav>
#      <nav>
#       <ul class="first_letter_menu">
#        <li>
#         <a href="/movies_letter-sign" title="Movies whose names started from sign or digit">
#          [sign or digit]
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-A" title='Movies transcripts started from letter "A"'>
#          A
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-B" title='Movies transcripts started from letter "B"'>
#          B
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-C" title='Movies transcripts started from letter "C"'>
#          C
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-D" title='Movies transcripts started from letter "D"'>
#          D
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-E" title='Movies transcripts started from letter "E"'>
#          E
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-F" title='Movies transcripts started from letter "F"'>
#          F
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-G" title='Movies transcripts started from letter "G"'>
#          G
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-H" title='Movies transcripts started from letter "H"'>
#          H
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-I" title='Movies transcripts started from letter "I"'>
#          I
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-J" title='Movies transcripts started from letter "J"'>
#          J
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-K" title='Movies transcripts started from letter "K"'>
#          K
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-L" title='Movies transcripts started from letter "L"'>
#          L
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-M" title='Movies transcripts started from letter "M"'>
#          M
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-N" title='Movies transcripts started from letter "N"'>
#          N
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-O" title='Movies transcripts started from letter "O"'>
#          O
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-P" title='Movies transcripts started from letter "P"'>
#          P
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-Q" title='Movies transcripts started from letter "Q"'>
#          Q
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-R" title='Movies transcripts started from letter "R"'>
#          R
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-S" title='Movies transcripts started from letter "S"'>
#          S
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-T" title='Movies transcripts started from letter "T"'>
#          T
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-U" title='Movies transcripts started from letter "U"'>
#          U
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-V" title='Movies transcripts started from letter "V"'>
#          V
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-W" title='Movies transcripts started from letter "W"'>
#          W
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-X" title='Movies transcripts started from letter "X"'>
#          X
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-Y" title='Movies transcripts started from letter "Y"'>
#          Y
#         </a>
#        </li>
#        <li>
#         <a href="/movies_letter-Z" title='Movies transcripts started from letter "Z"'>
#          Z
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <nav class="pagination_pages">
#       <nav>
#        <ul class="pagination">
#         <li aria-disabled="true" aria-label="« Previous" class="page-item disabled">
#          <span aria-hidden="true" class="page-link">
#           ‹
#          </span>
#         </li>
#         <li aria-current="page" class="page-item active">
#          <span class="page-link">
#           1
#          </span>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=2">
#           2
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=3">
#           3
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=4">
#           4
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=5">
#           5
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=6">
#           6
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=7">
#           7
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=8">
#           8
#          </a>
#         </li>
#         <li aria-disabled="true" class="page-item disabled">
#          <span class="page-link">
#           ...
#          </span>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=131">
#           131
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=132">
#           132
#          </a>
#         </li>
#         <li class="page-item">
#          <a aria-label="Next »" class="page-link" href="https://subslikescript.com/movies_letter-A?page=2" rel="next">
#           ›
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </nav>
#      <article class="main-article">
#       <h1>
#        Movies with the first letter - "A"
#       </h1>
#       <ul class="scripts-list">
#        <a href="movie/A_1000000000000000_Ransom-4926482" title="Subtitles to movie 'A ¥1,000,000,000,000,000 Ransom' in transcript view">
#         <li>
#          A ¥1,000,000,000,000,000 Ransom (2015)
#         </li>
#        </a>
#        <a href="movie/A_2nd_Chance-2150139" title="Subtitles to movie 'A 2nd Chance' in transcript view">
#         <li>
#          A 2nd Chance (2011)
#         </li>
#        </a>
#        <a href="movie/A_Aa-5684466" title="Subtitles to movie 'A Aa' in transcript view">
#         <li>
#          A Aa (2016)
#         </li>
#        </a>
#        <a href="movie/A_Babysitters_Guide_to_Monster_Hunting-4844150" title="Subtitles to movie 'A Babysitter's Guide to Monster Hunting' in transcript view">
#         <li>
#          A Babysitter's Guide to Monster Hunting (2020)
#         </li>
#        </a>
#        <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#        </script>
#        <!-- subslikescript horizontal adaptive media -->
#        <ins class="adsbygoogle" data-ad-client="ca-pub-6250492176235895" data-ad-format="auto" data-ad-slot="3851271050" data-full-width-responsive="true" style="display:block">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#        <a href="movie/A_Bad_Son-81678" title="Subtitles to movie 'A Bad Son' in transcript view">
#         <li>
#          A Bad Son (1980)
#         </li>
#        </a>
#        <a href="movie/A_Bag_of_Marbles-153414" title="Subtitles to movie 'A Bag of Marbles' in transcript view">
#         <li>
#          A Bag of Marbles (1975)
#         </li>
#        </a>
#        <a href="movie/A_Balloon_for_Allah-1880111" title="Subtitles to movie 'A Balloon for Allah' in transcript view">
#         <li>
#          A Balloon for Allah (2011)
#         </li>
#        </a>
#        <a href="movie/A_Banana_At_This_Time_of_Night-9010228" title="Subtitles to movie 'A Banana? At This Time of Night?' in transcript view">
#         <li>
#          A Banana? At This Time of Night? (2018)
#         </li>
#        </a>
#        <a href="movie/A_Banquet-11400902" title="Subtitles to movie 'A Banquet' in transcript view">
#         <li>
#          A Banquet (2021)
#         </li>
#        </a>
#        <a href="movie/A_Barefoot_Dream-1583213" title="Subtitles to movie 'A Barefoot Dream' in transcript view">
#         <li>
#          A Barefoot Dream (2010)
#         </li>
#        </a>
#        <a href="movie/A_Bear_Named_Winnie-437088" title="Subtitles to movie 'A Bear Named Winnie' in transcript view">
#         <li>
#          A Bear Named Winnie (2004)
#         </li>
#        </a>
#        <a href="movie/A_Beautiful_Curse-12593190" title="Subtitles to movie 'A Beautiful Curse' in transcript view">
#         <li>
#          A Beautiful Curse (2021)
#         </li>
#        </a>
#        <a href="movie/A_Beautiful_Day_in_the_Neighborhood-3224458" title="Subtitles to movie 'A Beautiful Day in the Neighborhood' in transcript view">
#         <li>
#          A Beautiful Day in the Neighborhood (2019)
#         </li>
#        </a>
#        <a href="movie/A_Beautiful_Mind-268978" title="Subtitles to movie 'A Beautiful Mind' in transcript view">
#         <li>
#          A Beautiful Mind (2001)
#         </li>
#        </a>
#        <a href="movie/A_Beautiful_Now-2611160" title="Subtitles to movie 'A Beautiful Now' in transcript view">
#         <li>
#          A Beautiful Now (2015)
#         </li>
#        </a>
#        <a href="movie/A_Beautiful_Place_to_Die_A_Marthas_Vineyard_Mystery-10768536" title="Subtitles to movie 'A Beautiful Place to Die: A Martha's Vineyard Mystery' in transcript view">
#         <li>
#          A Beautiful Place to Die: A Martha's Vineyard Mystery (2020)
#         </li>
#        </a>
#        <a href="movie/A_Beautiful_Planet-2800050" title="Subtitles to movie 'A Beautiful Planet' in transcript view">
#         <li>
#          A Beautiful Planet (2016)
#         </li>
#        </a>
#        <a href="movie/A_Beautiful_Secret-316562" title="Subtitles to movie 'A Beautiful Secret' in transcript view">
#         <li>
#          A Beautiful Secret (2002)
#         </li>
#        </a>
#        <a href="movie/A_Bee_in_August-970946" title="Subtitles to movie 'A Bee in August' in transcript view">
#         <li>
#          A Bee in August (2007)
#         </li>
#        </a>
#        <a href="movie/A_Belfast_Story-2326204" title="Subtitles to movie 'A Belfast Story' in transcript view">
#         <li>
#          A Belfast Story (2013)
#         </li>
#        </a>
#        <a href="movie/A_Belle_for_Christmas-3256812" title="Subtitles to movie 'A Belle for Christmas' in transcript view">
#         <li>
#          A Belle for Christmas (2014)
#         </li>
#        </a>
#        <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#        </script>
#        <!-- subslikescript horizontal adaptive media -->
#        <ins class="adsbygoogle" data-ad-client="ca-pub-6250492176235895" data-ad-format="auto" data-ad-slot="3851271050" data-full-width-responsive="true" style="display:block">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#        <a href="movie/A_Beloved_Wife-11288650" title="Subtitles to movie 'A Beloved Wife' in transcript view">
#         <li>
#          A Beloved Wife (2019)
#         </li>
#        </a>
#        <a href="movie/A_Bennett_Song_Holiday-8552834" title="Subtitles to movie 'A Bennett Song Holiday' in transcript view">
#         <li>
#          A Bennett Song Holiday (2020)
#         </li>
#        </a>
#        <a href="movie/A_Better_Tomorrow-92263" title="Subtitles to movie 'A Better Tomorrow' in transcript view">
#         <li>
#          A Better Tomorrow (1986)
#         </li>
#        </a>
#        <a href="movie/A_Better_Tomorrow_II-94357" title="Subtitles to movie 'A Better Tomorrow II' in transcript view">
#         <li>
#          A Better Tomorrow II (1987)
#         </li>
#        </a>
#        <a href="movie/A_Better_Way_to_Die-168504" title="Subtitles to movie 'A Better Way to Die' in transcript view">
#         <li>
#          A Better Way to Die (2000)
#         </li>
#        </a>
#        <a href="movie/A_Big_Love_Story-1769383" title="Subtitles to movie 'A Big Love Story' in transcript view">
#         <li>
#          A Big Love Story (2012)
#         </li>
#        </a>
#        <a href="movie/A_Bigger_Splash-2056771" title="Subtitles to movie 'A Bigger Splash' in transcript view">
#         <li>
#          A Bigger Splash (2015)
#         </li>
#        </a>
#        <a href="movie/A_Birders_Guide_to_Everything-1582465" title="Subtitles to movie 'A Birder's Guide to Everything' in transcript view">
#         <li>
#          A Birder's Guide to Everything (2013)
#         </li>
#        </a>
#        <a href="movie/A_Bit_of_Bad_Luck-2406306" title="Subtitles to movie 'A Bit of Bad Luck' in transcript view">
#         <li>
#          A Bit of Bad Luck (2014)
#         </li>
#        </a>
#       </ul>
#      </article>
#      <nav class="pagination_pages">
#       <nav>
#        <ul class="pagination">
#         <li aria-disabled="true" aria-label="« Previous" class="page-item disabled">
#          <span aria-hidden="true" class="page-link">
#           ‹
#          </span>
#         </li>
#         <li aria-current="page" class="page-item active">
#          <span class="page-link">
#           1
#          </span>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=2">
#           2
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=3">
#           3
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=4">
#           4
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=5">
#           5
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=6">
#           6
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=7">
#           7
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=8">
#           8
#          </a>
#         </li>
#         <li aria-disabled="true" class="page-item disabled">
#          <span class="page-link">
#           ...
#          </span>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=131">
#           131
#          </a>
#         </li>
#         <li class="page-item">
#          <a class="page-link" href="https://subslikescript.com/movies_letter-A?page=132">
#           132
#          </a>
#         </li>
#         <li class="page-item">
#          <a aria-label="Next »" class="page-link" href="https://subslikescript.com/movies_letter-A?page=2" rel="next">
#           ›
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </nav>
#     </main>
#     <div class="left-side">
#     </div>
#     <div class="right-side">
#     </div>
#    </div>
#    <!--main-wrapper div ending-->
#    <footer>
#     <span class="contactus">
#      Have any questions? Contact us: subslikescript(doggysign)gmail.com |
#      <a href="/dmca">
#       DMCA
#      </a>
#     </span>
#    </footer>
#   </div>
#   <!-- wrapper ends -->
#  </body>
# </html>
# movie/A_1000000000000000_Ransom-4926482
# movie/A_2nd_Chance-2150139
# movie/A_Aa-5684466
# movie/A_Babysitters_Guide_to_Monster_Hunting-4844150
# movie/A_Bad_Son-81678
# movie/A_Bag_of_Marbles-153414
# movie/A_Balloon_for_Allah-1880111
# movie/A_Banana_At_This_Time_of_Night-9010228
# ------link not working-------
# movie/A_Banana_At_This_Time_of_Night-9010228
# movie/A_Banquet-11400902
# movie/A_Barefoot_Dream-1583213
# movie/A_Bear_Named_Winnie-437088
# movie/A_Beautiful_Curse-12593190
# movie/A_Beautiful_Day_in_the_Neighborhood-3224458
# movie/A_Beautiful_Mind-268978
# movie/A_Beautiful_Now-2611160
# movie/A_Beautiful_Place_to_Die_A_Marthas_Vineyard_Mystery-10768536
# movie/A_Beautiful_Planet-2800050
# movie/A_Beautiful_Secret-316562
# movie/A_Bee_in_August-970946
# movie/A_Belfast_Story-2326204
# movie/A_Belle_for_Christmas-3256812
# movie/A_Beloved_Wife-11288650
# movie/A_Bennett_Song_Holiday-8552834
# movie/A_Better_Tomorrow-92263
# movie/A_Better_Tomorrow_II-94357
# movie/A_Better_Way_to_Die-168504
# movie/A_Big_Love_Story-1769383
# movie/A_Bigger_Splash-2056771
# movie/A_Birders_Guide_to_Everything-1582465
# movie/A_Bit_of_Bad_Luck-2406306
# movie/A_1000000000000000_Ransom-4926482
# movie/A_2nd_Chance-2150139
# movie/A_Aa-5684466
# movie/A_Babysitters_Guide_to_Monster_Hunting-4844150
# movie/A_Bad_Son-81678
# movie/A_Bag_of_Marbles-153414
# movie/A_Balloon_for_Allah-1880111
# movie/A_Banana_At_This_Time_of_Night-9010228
# ------link not working-------
# movie/A_Banana_At_This_Time_of_Night-9010228
# movie/A_Banquet-11400902
# movie/A_Barefoot_Dream-1583213
# movie/A_Bear_Named_Winnie-437088
# movie/A_Beautiful_Curse-12593190
# movie/A_Beautiful_Day_in_the_Neighborhood-3224458
# movie/A_Beautiful_Mind-268978
# movie/A_Beautiful_Now-2611160
# movie/A_Beautiful_Place_to_Die_A_Marthas_Vineyard_Mystery-10768536
# movie/A_Beautiful_Planet-2800050
# movie/A_Beautiful_Secret-316562
# movie/A_Bee_in_August-970946
# movie/A_Belfast_Story-2326204
# movie/A_Belle_for_Christmas-3256812
# movie/A_Beloved_Wife-11288650
# movie/A_Bennett_Song_Holiday-8552834
# movie/A_Better_Tomorrow-92263
# movie/A_Better_Tomorrow_II-94357
# movie/A_Better_Way_to_Die-168504
# movie/A_Big_Love_Story-1769383
# movie/A_Bigger_Splash-2056771
# movie/A_Birders_Guide_to_Everything-1582465
# movie/A_Bit_of_Bad_Luck-2406306
# movie/A_Bittersweet_Life-456912
# movie/A_Black_Veil_for_Lisa-63323
# movie/A_Blast-3813916
# movie/A_Blue_Ridge_Mountain_Christmas-10936658
# movie/A_Bluebird_in_My_Heart-6921496
# movie/A_Bomb_Was_Stolen-131571
# movie/A_Borrowed_Life-109691
# movie/A_Boss_in_the_Living_Room-3296204
# movie/A_Box_of_Faith-5007774
# movie/A_Boy_a_Girl_and_a_Dead_Cat-405798
# movie/A_Boy_and_His_Dog-72730
# movie/A_Boy_and_Sungreen-10402898
# movie/A_Boy_Called_Christmas-10187208
# movie/A_Boy_Called_Dad-1433514
# movie/A_Boy_Called_Sailboat-2201211
# movie/A_Boy_A_Girl_A_Dream-6905402
# movie/A_Brand_New_Life-1287875
# movie/A_Breath_of_Scandal-53675
# movie/A_Breed_Apart-87001
# movie/A_Bride_for_Christmas-2415112
# movie/A_Brides_Revenge-9287408
# movie/A_Bridge_Too_Far-75784
# movie/A_Brief_Message_from_the_Heart-171572
# movie/A_Brief_Vacation-69823
# movie/A_Brighter_Summer_Day-101985
# movie/A_Brilliant_Monster-6534422
# movie/A_Broken_Drum-42056
# movie/A_Bronx_Tale-106489
# movie/A_Brony_Tale-3219678
# movie/A_Brother-9369620
